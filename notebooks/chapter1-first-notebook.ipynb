# %% [markdown]
# # My First Jupyter Notebook
#
# This notebook is part of my Jupyter Notebook practice. It covers the basics of creating and running cells.

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
name = "John"
print(name)
# Out:
# John

# %% [markdown]
# ## What I learned
#
# - how to create a notebook
# - how to run code cells
# - how Markdown and code cells work together

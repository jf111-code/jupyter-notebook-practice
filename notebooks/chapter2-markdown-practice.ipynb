# %% [markdown]
# # Chapter 2 Markdown Practice
#
# This notebook is part of my Jupyter Notebook practice. It focuses on using Markdown to create structure, explanation, and readable notes inside a notebook.

# %% [markdown]
# ## What I’m practicing
#
# In this notebook, I am practicing:
#
# - headings
# - bold and italic text
# - bullet lists
# - numbered lists
# - links
# - inline code formatting

# %% [markdown]
# ## Simple formatting examples
#
# **Bold text** helps emphasize key ideas.
#
# *Italic text* can add subtle emphasis.
#
# You can also combine them: ***bold + italic***.

# %% [markdown]
# ## Lists
#
# ### Bullet list
# - Jupyter Notebook
# - Markdown
# - Python
# - GitHub
#
# ### Numbered list
# 1. Create a notebook
# 2. Add Markdown cells
# 3. Add code cells
# 4. Push to GitHub

# %% [markdown]
# ## Links and code formatting
#
# Here is a link to [GitHub](https://github.com).
#
# Inline code looks like this: `print("Hello, Jupyter!")`

# %%
message = "Markdown makes notebooks easier to read."
print(message)

# %% [markdown]
# ## Why Markdown matters
#
# Markdown helps turn a notebook into a readable document instead of just a sequence of code cells.
#
# That matters for:
# - learning
# - communication
# - GitHub presentation
# - portfolio quality

# %% [markdown]
# ## What I learned
#
# - Markdown and code cells serve different purposes
# - Markdown improves notebook organization
# - Clean formatting makes notebooks easier to share on GitHub

# %% [markdown]
# ## Personal Reflection
#
# In this notebook, I practiced using Markdown to structure and explain ideas.
#
# I can see how Markdown makes notebooks more readable and useful for sharing work on GitHub.
#
# Going forward, I want to combine clear explanations with code to build better projects.
